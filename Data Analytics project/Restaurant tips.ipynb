# %% [markdown]
# # Data Analytics project
#
# - step-1. Bussiness problem understanding
#
#          - understand the bussiness problems(project)
#          - Understand client requirements(understand they want)
#          - understand what they are expecting from you
# **Note:if step is not clear,never jump into step 2**
#
# - step-2. Data understanding
#
#         - collect data from source
#         - Data exploration
#
#              - understanding every column name very clarly( either by reserch, by asking seniors)
#              - understand each variable clearly by applying descriptive stastistics
#              - observe the complete given data ,by applying pandas & seaborn
#
# - step-3.Data preprocessing & Data prepration
#
#   - Data Cleaning
#
#          - wrong data
#          - wrong data type
#          - duplicates
#          - missing values
#          - outliers
#     **After the data cleaning completed ,store data as a cleaned data**
# - step-4. Analysis
#
#     - applying various logics as per project requirements
#     - interference/observation  on your logic
#     - interference/observation is important,write in the notes
#
# **List is observation ,what you have written in the notes----> Reports**
#
# - presentation

# %% [markdown]
# # Step-1. Bussiness problem
#
#   - Restaurant owner wants detailed report on sales
#   - whaever the data i have provided, from that do analysis & submit
#     submit your reports/inferences

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.simplefilter("ignore")

# %% [markdown]
# Step2.1: load the data

# %%
df= pd.read_csv('C:\\Users\\salma\\Downloads\\tips.csv')
df
# Out:
#      total_bill   tip     sex smoker   day    time  size  price_per_person  \
# 0         16.99  1.01  Female     No   Sun  Dinner     2              8.49
# 1         10.34  1.66    Male     No   Sun  Dinner     3              3.45
# 2         21.01  3.50    Male     No   Sun  Dinner     3              7.00
# 3         23.68  3.31    Male     No   Sun  Dinner     2             11.84
# 4         24.59  3.61  Female     No   Sun  Dinner     4              6.15
# ..          ...   ...     ...    ...   ...     ...   ...               ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3              9.68
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2             13.59
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2             11.34
# 242       17.82  1.75    Male     No   Sat  Dinner     2              8.91
# 243       18.78  3.00  Female     No  Thur  Dinner     2              9.39
#
#              Payer Name         CC Number Payment ID
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   total_bill        244 non-null    float64
#  1   tip               244 non-null    float64
#  2   sex               244 non-null    object
#  3   smoker            244 non-null    object
#  4   day               244 non-null    object
#  5   time              244 non-null    object
#  6   size              244 non-null    int64
#  7   price_per_person  244 non-null    float64
#  8   Payer Name        244 non-null    object
#  9   CC Number         244 non-null    int64
#  10  Payment ID        244 non-null    object
# dtypes: float64(3), int64(2), object(6)
# memory usage: 21.1+ KB

# %%
pd.crosstab(df["day"],df["time"],margins=True)
# Out:
# time  Dinner  Lunch  All
# day
# Fri       12      7   19
# Sat       87      0   87
# Sun       76      0   76
# Thur       1     61   62
# All      176     68  244

# %%
# on which day and time ,total bill is more

df.groupby("day")["total_bill"].max()
# Out:
# day
# Fri     40.17
# Sat     50.81
# Sun     48.17
# Thur    43.11
# Name: total_bill, dtype: float64

# %%
sns.catplot(x="day",y="total_bill",hue="time",data=df)

# %%
pd.crosstab(df["size"],df["day"],margins=True)
# Out:
# day   Fri  Sat  Sun  Thur  All
# size
# 1       1    2    0     1    4
# 2      16   53   39    48  156
# 3       1   18   15     4   38
# 4       1   13   18     5   37
# 5       0    1    3     1    5
# 6       0    0    1     3    4
# All    19   87   76    62  244

# %%
df["total_bill"].describe()
# Out:
# count    244.000000
# mean      19.785943
# std        8.902412
# min        3.070000
# 25%       13.347500
# 50%       17.795000
# 75%       24.127500
# max       50.810000
# Name: total_bill, dtype: float64

# %%
df["tip"].describe()
# Out:
# count    244.000000
# mean       2.998279
# std        1.383638
# min        1.000000
# 25%        2.000000
# 50%        2.900000
# 75%        3.562500
# max       10.000000
# Name: tip, dtype: float64

# %%
df["sex"].unique()
# Out:
# array(['Female', 'Male'], dtype=object)

# %%
df["sex"].value_counts()
# Out:
# sex
# Male      157
# Female     87
# Name: count, dtype: int64

# %%
df["smoker"].unique()
# Out:
# array(['No', 'Yes'], dtype=object)

# %%
df["smoker"].value_counts()
# Out:
# smoker
# No     151
# Yes     93
# Name: count, dtype: int64

# %%
# Gender-wise smoker count
df.groupby(['sex', 'smoker']).size()
# Out:
# sex     smoker
# Female  No        54
#         Yes       33
# Male    No        97
#         Yes       60
# dtype: int64

# %%
df["day"].unique()
# Out:
# array(['Sun', 'Sat', 'Thur', 'Fri'], dtype=object)

# %%
df["day"].value_counts
()
# Out:
# ()

# %%
df["time"].unique()
# Out:
# array(['Dinner', 'Lunch'], dtype=object)

# %%
df["time"].value_counts()
# Out:
# time
# Dinner    176
# Lunch      68
# Name: count, dtype: int64

# %%
df["size"].unique()
# Out:
# array([2, 3, 4, 1, 6, 5], dtype=int64)

# %%
df["size"].value_counts()
# Out:
# size
# 2    156
# 3     38
# 4     37
# 5      5
# 1      4
# 6      4
# Name: count, dtype: int64

# %%
continous=['total_bill','tip']
discrete_categorical=['sex','smoker','day','time']
discrete_count=["size"]

# %% [markdown]
# ### Discriptive stastistics

# %%
df[continous].describe()
# Out:
#        total_bill         tip
# count  244.000000  244.000000
# mean    19.785943    2.998279
# std      8.902412    1.383638
# min      3.070000    1.000000
# 25%     13.347500    2.000000
# 50%     17.795000    2.900000
# 75%     24.127500    3.562500
# max     50.810000   10.000000

# %% [markdown]
# "What is Skewness?"
#
# Skewness is a statistical measure that tells us how much a distribution (data) is asymmetrical — that is, how much it leans or "skews" to the left or right, rather than being perfectly balanced like a normal (bell-shaped) distribution.
#
# 📈 Types of Skewness:
# Skewness = 0
# → Perfectly symmetric (e.g., normal distribution)
#
# Positive Skew (Right Skew):
# → Tail is longer on the right side
# → Mean > Median
# → Example: Income data (most people earn less, a few earn a lot)
#
# Negative Skew (Left Skew):
# → Tail is longer on the left side
# → Mean < Median
# → Example: Test scores where most students scored high, few scored low

# %%
df[continous].skew()
# Out:
# total_bill    1.133213
# tip           1.465451
# dtype: float64

# %%
plt.hist(df["total_bill"],bins=10)
# Out:
# (array([ 7., 42., 68., 51., 31., 19., 12.,  7.,  3.,  4.]),
#  array([ 3.07 ,  7.844, 12.618, 17.392, 22.166, 26.94 , 31.714, 36.488,
#         41.262, 46.036, 50.81 ]),
#  <BarContainer object of 10 artists>)

# %%
plt.boxplot(df["total_bill"])   # outlier check
plt.show()

# %% [markdown]
# # obsevation
#
# - total_bill is right skewed (positive skew)
# - tip is also right skewed
# - some outlier

# %%
df[discrete_categorical].describe()
# Out:
#          sex smoker  day    time
# count    244    244  244     244
# unique     2      2    4       2
# top     Male     No  Sat  Dinner
# freq     157    151   87     176

# %% [markdown]
# #
# Step-3:DAta Preprocessing

# %%
#
df=df.drop_duplicates() #drop duplicated value

# %%
df.shape
# Out:
# (244, 11)

# %%
df.isnull().sum() # check missing value
# Out:
# total_bill          0
# tip                 0
# sex                 0
# smoker              0
# day                 0
# time                0
# size                0
# price_per_person    0
# Payer Name          0
# CC Number           0
# Payment ID          0
# dtype: int64

# %%
#treat outlier
# retrain the ouutliers

# %% [markdown]
# ### Step-4:Analysis
# - pandas and eaborn

# %%
df.groupby("sex")['total_bill'].describe().transpose()
# Out:
# sex       Female        Male
# count  87.000000  157.000000
# mean   18.056897   20.744076
# std     8.009209    9.246469
# min     3.070000    7.250000
# 25%    12.750000   14.000000
# 50%    16.400000   18.350000
# 75%    21.520000   24.710000
# max    44.300000   50.810000

# %%
df.groupby("day")['total_bill'].describe().transpose()
# Out:
# day          Fri        Sat        Sun       Thur
# count  19.000000  87.000000  76.000000  62.000000
# mean   17.151579  20.441379  21.410000  17.682742
# std     8.302660   9.480419   8.832122   7.886170
# min     5.750000   3.070000   7.250000   7.510000
# 25%    12.095000  13.905000  14.987500  12.442500
# 50%    15.380000  18.240000  19.630000  16.200000
# 75%    21.750000  24.740000  25.597500  20.155000
# max    40.170000  50.810000  48.170000  43.110000

# %%
df.groupby("time")['total_bill'].describe().transpose()
# Out:
# time       Dinner      Lunch
# count  176.000000  68.000000
# mean    20.797159  17.168676
# std      9.142029   7.713882
# min      3.070000   7.510000
# 25%     14.437500  12.235000
# 50%     18.390000  15.965000
# 75%     25.282500  19.532500
# max     50.810000  43.110000

# %%
pd.crosstab(df["sex"],df["time"])
# Out:
# time    Dinner  Lunch
# sex
# Female      52     35
# Male       124     33

# %%
pd.crosstab(df["sex"],df["day"])
# Out:
# day     Fri  Sat  Sun  Thur
# sex
# Female    9   28   18    32
# Male     10   59   58    30

# %% [markdown]
# # plot's for continous data
#
# 1.univariate(single variable)
#
#    - histogram
#    - Boxplot
#
# 2.Bivariate(plot between two variable)
#
#    - Scatter plot
#    - line plot
#    - joint plot
#    - violin plot
#
# 3.Multivariate(more than 2 variable)
#
#    - pair plot
#    - heatmap

# %% [markdown]
# # histogram/Distribution plot

# %%
sns.histplot(df['total_bill'],bins=10,kde=True)
# Out:
# <Axes: xlabel='total_bill', ylabel='Count'>

# %%
sns.kdeplot(df['total_bill'])
plt.show()

# %% [markdown]
# # box plot

# %%
sns.boxplot(x=df["tip"])
plt.show()

# %%
sns.boxplot(y=df["total_bill"])
plt.show()

# %% [markdown]
# ### Scatter plot

# %% [markdown]
# **scatter plot using 3 variable**
# - 2 continous variable
#  - 1 discrete variable
#
# basically scatter lot is applied on  2 continous variable, if yuo want 3rd variable ,it should be compulsary discrete

# %%
sns.scatterplot(x=df['total_bill'],y=df['tip'])
plt.show()

# %%
sns.scatterplot(x=df['total_bill'],y= df['tip'],hue=df["sex"])
plt.show()     # hue means diffrent colours

# %%
import matplotlib.pyplot as plt

male = df[df["sex"] == "Male"]
female = df[df["sex"] == "Female"]

plt.scatter(male["total_bill"], male["tip"], color="blue", label="Male")
plt.scatter(female["total_bill"], female["tip"], color="orange", label="Female")

plt.xlabel("Total Bill")
plt.ylabel("Tip")
plt.title("Tip vs Total Bill by Gender")
plt.legend()
plt.show()

# %%
sns.relplot(x=df['total_bill'],y= df['tip'],col=df['size'],col_wrap=2,hue=df["sex"])
plt.show()

# %% [markdown]
# ### Line plot

# %%
import numpy as np
df['sno']=pd.DataFrame(np.arange(1,245))
df
# Out:
#      total_bill   tip     sex smoker   day    time  size  price_per_person  \
# 0         16.99  1.01  Female     No   Sun  Dinner     2              8.49
# 1         10.34  1.66    Male     No   Sun  Dinner     3              3.45
# 2         21.01  3.50    Male     No   Sun  Dinner     3              7.00
# 3         23.68  3.31    Male     No   Sun  Dinner     2             11.84
# 4         24.59  3.61  Female     No   Sun  Dinner     4              6.15
# ..          ...   ...     ...    ...   ...     ...   ...               ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3              9.68
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2             13.59
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2             11.34
# 242       17.82  1.75    Male     No   Sat  Dinner     2              8.91
# 243       18.78  3.00  Female     No  Thur  Dinner     2              9.39
#
#              Payer Name         CC Number Payment ID  sno
# ...

# %%
sns.relplot(x='sno',y='tip',data=df,kind="line")
plt.show()

# %%
df.drop("sno",axis=1,inplace=True)

# %% [markdown]
# joint plot

# %%
sns.jointplot(x="total_bill",y="tip",data=df)
plt.show()

# %% [markdown]
# violin plot

# %%
sns.violinplot(x="total_bill",y="sex",data=df)
plt.show()

# %% [markdown]
# pair pllot-multiple continous variables

# %%
sns.pairplot(df,vars=continous)
plt.show()

# %%
c_m = df[continous].corr()
c_m
# Out:
#             total_bill       tip
# total_bill    1.000000  0.675734
# tip           0.675734  1.000000

# %%
sns.heatmap(c_m,annot=True)
plt.show()

# %% [markdown]
# ### count plot

# %%
df['smoker'].unique()
# Out:
# array(['No', 'Yes'], dtype=object)

# %%
df['smoker'].value_counts()
# Out:
# smoker
# No     151
# Yes     93
# Name: count, dtype: int64

# %%
sns.countplot(x='smoker',data=df)
plt.show()

# %% [markdown]
# bar plot

# %%
df.groupby("sex")["total_bill"].mean()
# Out:
# sex
# Female    18.056897
# Male      20.744076
# Name: total_bill, dtype: float64

# %%
sns.catplot(x='sex',y='total_bill',data=df,kind='bar')
plt.show()

# %%
df.groupby("smoker")["total_bill"].mean()
# Out:
# smoker
# No     19.188278
# Yes    20.756344
# Name: total_bill, dtype: float64

# %%
sns.catplot(x='smoker',y='total_bill',data=df,kind='bar')
plt.show()

# %%
sns.catplot(x='day',y='total_bill',data=df,hue="size",kind='bar')
plt.show()

# %%
sns.catplot(x='day',y='total_bill',data=df,kind='bar')
plt.show()

# %%
sns.catplot(x='day',y='total_bill',data=df,kind='bar',hue="sex")
plt.show()

# %% [markdown]
# box plot

# %%
sns.catplot(x="day",y="total_bill",data=df)
plt.show()

# %%
sns.catplot(x="day",y="total_bill",data=df,kind="box")
plt.show()

# %%
sns.catplot(x="day",y="total_bill",data=df,kind="box",hue="sex")
plt.show()
